# %% [markdown]
# ### Steps to create Dataset
# * Get raw data from MongoDB
# * Map to target variables
# * Convert target variable to int
# * Split into Train/Test
# * Downlaod Tokenizer
# * Tokenize train/test set

# %%
import random

from transformers import AutoTokenizer, DistilBertTokenizerFast
from typing import List
from datasets import Dataset

import pandas as pd
from pandas import DataFrame
from pymongo import MongoClient
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure

sns.set_style("white")

mongo_client = MongoClient("127.0.0.1")

mongo_db = mongo_client["nvd"]
mongo_collection = mongo_db["nvd_all"]
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
tokenizer: DistilBertTokenizerFast = AutoTokenizer.from_pretrained("distilbert-base-uncased")

# %% [markdown]
# ## Get Descriptions into DataFrame

# %%
data_descriptions: List = list(mongo_collection.aggregate([
    {
        '$match': {
            'cvssv3': {
                '$nin': [
                    'None', ''
                ]
            }
        }
    }, {
        '$unwind': {
            'path': '$description'
        }
    }, {
        '$project': {
            'year': 0,
            'reference_data': 0,
            'cwe': 0,
            'cvssv2': 0,
            'cpe': 0,
            'references': 0
        }
    }, {
        '$project': {
            'text': '$description',
            'cvssv3': 1
        }
    }
]))
data_references: List = list(mongo_collection.aggregate([
    {
        '$match': {
            'cvssv3': {
                '$nin': [
                    'None', ''
                ]
            }
        }
    }, {
        '$unwind': {
            'path': '$reference_data'
        }
    }, {
        '$replaceRoot': {
            'newRoot': {
                '$mergeObjects': [
                    '$$ROOT', '$reference_data'
                ]
            }
        }
    }, {
        '$match': {
            'text_selenium': {
                '$exists': 1
            }
        }
    }, {
        '$project': {
            'year': 0,
            'reference_data': 0,
            'cwe': 0,
            'cvssv2': 0,
            'cpe': 0,
            'references': 0,
            'description': 0,
            'url': 0,
            'name': 0,
            'refsource': 0,
            'scraped_selenium': 0,
            'tags': 0
        }
    }, {
        '$project': {
            'text': '$text_selenium',
            'cvssv3': 1
        }
    }
]))

# %%
rows = []
data = data_references + data_descriptions
for row in data:
    id = row['_id']
    text = row['text']
    cvss = row['cvssv3']
    cvss_arr: List[str] = cvss.split('/')
    av: str = cvss_arr[1].replace('AV:', '')
    ac: str = cvss_arr[2].replace('AC:', '')
    pr: str = cvss_arr[3].replace('PR:', '')
    ui: str = cvss_arr[4].replace('UI:', '')
    s: str = cvss_arr[5].replace('S:', '')
    c: str = cvss_arr[6].replace('C:', '')
    i: str = cvss_arr[7].replace('I:', '')
    a: str = cvss_arr[8].replace('A:', '')
    score: float = float(cvss_arr[9].replace('Score:', ''))
    rows.append([id, text, av, ac, pr, ui, s, c, i, a, score])

df = pd.DataFrame(rows, columns=['id', 'text', 'av', 'ac', 'pr', 'ui', 's', 'c', 'i', 'a', 'score'])
df.to_csv('full_dataset.csv', index=False)
df.head()
# Out:
#               id                                               text av ac pr  \
# 0  CVE-2021-0001  A potential security vulnerability in the Inte...  L  H  L
# 1  CVE-2021-0002  Potential security vulnerabilities in some Int...  L  L  L
# 2  CVE-2021-0003  Potential security vulnerabilities in some Int...  L  L  L
# 3  CVE-2021-0004  Potential security vulnerabilities in the firm...  L  L  H
# 4  CVE-2021-0005  Potential security vulnerabilities in the firm...  L  L  H
#
#   ui  s  c  i  a  score
# 0  N  U  H  N  N    4.7
# 1  N  U  H  N  H    7.1
# 2  N  U  H  N  N    5.5
# 3  N  U  N  N  H    4.4
# 4  N  U  N  N  H    4.4

# %%
df.shape
# Out:
# (101734, 11)

# %% [markdown]
# ## Create Dataset

# %%
TEST_SPLIT = 25

df_group: DataFrame = df.groupby(['id'])
df_group.head()
# Out:
#                    id                                               text av  \
# 0       CVE-2021-0001  A potential security vulnerability in the Inte...  L
# 1       CVE-2021-0002  Potential security vulnerabilities in some Int...  L
# 2       CVE-2021-0003  Potential security vulnerabilities in some Int...  L
# 3       CVE-2021-0004  Potential security vulnerabilities in the firm...  L
# 4       CVE-2021-0005  Potential security vulnerabilities in the firm...  L
# ...               ...                                                ... ..
# 101729  CVE-2016-9992  IBM Kenexa LCMS Premier on Cloud 9.0, and 10.0...  N
# 101730  CVE-2016-9993  IBM Kenexa LCMS Premier on Cloud 9.0, and 10.0...  N
# 101731  CVE-2016-9994  IBM Kenexa LCMS Premier on Cloud 9.0, and 10.0...  N
# 101732  CVE-2016-9997  SPIP 3.1.x suffers from a Reflected Cross Site...  N
# 101733  CVE-2016-9998  SPIP 3.1.x suffer from a Reflected Cross Site ...  N
#
#        ac pr ui  s  c  i  a  score
# 0       H  L  N  U  H  N  N    4.7
# 1       L  L  N  U  H  N  H    7.1
# 2       L  L  N  U  H  N  N    5.5
# 3       L  H  N  U  N  N  H    4.4
# 4       L  H  N  U  N  N  H    4.4
# ...    .. .. .. .. .. .. ..    ...
# 101729  L  L  N  U  H  L  N    7.1
# 101730  L  L  N  U  H  L  N    7.1
# 101731  L  L  N  U  H  L  N    7.1
# 101732  L  N  R  C  L  L  N    6.1
# 101733  L  N  R  C  L  L  N    6.1
#
# [101400 rows x 11 columns]

# %%
train_rows = []
test_rows = []
for id in df_group.groups.keys():
    ratio = len(train_rows) / (len(test_rows) + len(train_rows)) if len(train_rows) else 0
    if ratio > 0.75:
        g_df: DataFrame = df_group.get_group(id)
        test_rows.append(g_df.values)
    else:
        g_df: DataFrame = df_group.get_group(id)
        train_rows.append(g_df.values)


df_train = pd.DataFrame(train_rows, columns=['id', 'text', 'av', 'ac', 'pr', 'ui', 's', 'c', 'i', 'a', 'score'])
df_test = pd.DataFrame(test_rows, columns=['id', 'text', 'av', 'ac', 'pr', 'ui', 's', 'c', 'i', 'a', 'score'])
print(df_train.shape)
print(df_test.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 13>()
#       9         g_df: DataFrame = df_group.get_group(id)
#      10         train_rows.append(g_df.values)
# ---> 13 df_train = pd.DataFrame(train_rows, columns=['id', 'text', 'av', 'ac', 'pr', 'ui', 's', 'c', 'i', 'a', 'score'])
#      14 df_test = pd.DataFrame(test_rows, columns=['id', 'text', 'av', 'ac', 'pr', 'ui', 's', 'c', 'i', 'a', 'score'])
#      15 print(df_train.shape)
#
# File ~/.local/share/virtualenvs/selenium_parser-P8wiofQ8/lib/python3.10/site-packages/pandas/core/frame.py:737, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     729         mgr = arrays_to_mgr(
#     730             arrays,
#     731             columns,
#    (...)
#     734             typ=manager,
#     735         )
#     736     else:
# --> 737         mgr = ndarray_to_mgr(
#     738             data,
#     739             index,
#     740             columns,
#     741             dtype=dtype,
#     742             copy=copy,
#     743             typ=manager,
#     744         )
#     745 else:
#     746     mgr = dict_to_mgr(
#     747         {},
#     748         index,
#    (...)
#     751         typ=manager,
#     752     )
#
# File ~/.local/share/virtualenvs/selenium_parser-P8wiofQ8/lib/python3.10/site-packages/pandas/core/internals/construction.py:331, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     326         values = values.reshape(-1, 1)
#     328 else:
#     329     # by definition an array here
#     330     # the dtypes will be coerced to a single dtype
# --> 331     values = _prep_ndarray(values, copy=copy_on_sanitize)
#     333 if dtype is not None and not is_dtype_equal(values.dtype, dtype):
#     334     shape = values.shape
#
# File ~/.local/share/virtualenvs/selenium_parser-P8wiofQ8/lib/python3.10/site-packages/pandas/core/internals/construction.py:576, in _prep_ndarray(values, copy)
#     572 # we could have a 1-dim or 2-dim list here
#     573 # this is equiv of np.asarray, but does object conversion
#     574 # and platform dtype preservation
#     575 if is_list_like(values[0]):
# --> 576     values = np.array([convert(v) for v in values])
#     577 elif isinstance(values[0], np.ndarray) and values[0].ndim == 0:
#     578     # GH#21861 see test_constructor_list_of_lists
#     579     values = np.array([convert(v) for v in values])
#
# File ~/.local/share/virtualenvs/selenium_parser-P8wiofQ8/lib/python3.10/site-packages/pandas/core/internals/construction.py:576, in <listcomp>(.0)
#     572 # we could have a 1-dim or 2-dim list here
#     573 # this is equiv of np.asarray, but does object conversion
#     574 # and platform dtype preservation
#     575 if is_list_like(values[0]):
# --> 576     values = np.array([convert(v) for v in values])
#     577 elif isinstance(values[0], np.ndarray) and values[0].ndim == 0:
#     578     # GH#21861 see test_constructor_list_of_lists
#     579     values = np.array([convert(v) for v in values])
#
# File ~/.local/share/virtualenvs/selenium_parser-P8wiofQ8/lib/python3.10/site-packages/pandas/core/internals/construction.py:569, in _prep_ndarray.<locals>.convert(v)
#     566     return v
#     568 v = extract_array(v, extract_numpy=True)
# --> 569 res = maybe_convert_platform(v)
#     570 return res
#
# File ~/.local/share/virtualenvs/selenium_parser-P8wiofQ8/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:130, in maybe_convert_platform(values)
#     128 if arr.dtype == _dtype_obj:
#     129     arr = cast(np.ndarray, arr)
# --> 130     arr = lib.maybe_convert_objects(arr)
#     132 return arr
#
# File ~/.local/share/virtualenvs/selenium_parser-P8wiofQ8/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2395, in pandas._libs.lib.maybe_convert_objects()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 2)

# %%
train_rows = []
test_rows = []

x = 0
for i, o in df_group.iterrows():
    x += o['obs']
    ratio = len(train_rows) / (len(test_rows) + len(train_rows)) if len(train_rows) else 0
    if ratio > 0.75:
        test_rows.append(df[df['id'] == o['id']])
    else:
        train_rows.append(df[df['id'] == o['id']])
    if x % 100 == 0:
        print(x)

df_train = pd.DataFrame(train_rows, columns=['id', 'text', 'av', 'ac', 'pr', 'ui', 's', 'c', 'i', 'a', 'score'])
df_test = pd.DataFrame(test_rows, columns=['id', 'text', 'av', 'ac', 'pr', 'ui', 's', 'c', 'i', 'a', 'score'])
print(df_train.shape)
print(df_test.shape)
# Out:
# 700
# 800
# 900
# 1100
# 1400
# 1700
# 2000
# 2300
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000
# 25100
# 25200
# 25300
# 25400
# 25500
# 25600
# 25700
# 25800
# 25900
# 26000
# 26100
# 26200
# 26300
# 26400
# 26500
# 26600
# 26700
# 26800
# 26900
# 27000
# 27100
# 27200
# 27300
# 27400
# 27500
# 27600
# 27700
# 27800
# 27900
# 28000
# 28100
# 28200
# 28300
# 28400
# 28500
# 28600
# 28700
# 28800
# 28900
# 29000
# 29100
# 29200
# 29300
# 29400
# 29500
# 29600
# 29700
# 29800
# 29900
# 30000
# 30100
# 30200
# 30300
# 30400
# 30500
# 30600
# 30700
# 30800
# 30900
# 31000
# 31100
# 31200
# 31300
# 31400
# 31500
# 31600
# 31700
# 31800
# 31900
# 32000
# 32100
# 32200
# 32300
# 32400
# 32500
# 32600
# 32700
# 32800
# 32900
# 33000
# 33100
# 33200
# 33300
# 33400
# 33500
# 33600
# 33700
# 33800
# 33900
# 34000
# 34100
# 34200
# 34300
# 34400
# 34500
# 34600
# 34700
# 34800
# 34900
# 35000
# 35100
# 35200
# 35300
# 35400
# 35500
# 35600
# 35700
# 35800
# 35900
# 36000
# 36100
# 36200
# 36300
# 36400
# 36500
# 36600
# 36700
# 36800
# 36900
# 37000
# 37100
# 37200
# 37300
# 37400
# 37500
# 37600
# 37700
# 37800
# 37900
# 38000
# 38100
# 38200
# 38300
# 38400
# 38500
# 38600
# 38700
# 38800
# 38900
# 39000
# 39100
# 39200
# 39300
# 39400
# 39500
# 39600
# 39700
# 39800
# 39900
# 40000
# 40100
# 40200
# 40300
# 40400
# 40500
# 40600
# 40700
# 40800
# 40900
# 41000
# 41100
# 41200
# 41300
# 41400
# 41500
# 41600
# 41700
# 41800
# 41900
# 42000
# 42100
# 42200
# 42300
# 42400
# 42500
# 42600
# 42700
# 42800
# 42900
# 43000
# 43100
# 43200
# 43300
# 43400
# 43500
# 43600
# 43700
# 43800
# 43900
# 44000
# 44100
# 44200
# 44300
# 44400
# 44500
# 44600
# 44700
# 44800
# 44900
# 45000
# 45100
# 45200
# 45300
# 45400
# 45500
# 45600
# 45700
# 45800
# 45900
# 46000
# 46100
# 46200
# 46300
# 46400
# 46500
# 46600
# 46700
# 46800
# 46900
# 47000
# 47100
# 47200
# 47300
# 47400
# 47500
# 47600
# 47700
# 47800
# 47900
# 48000
# 48100
# 48200
# 48300
# 48400
# 48500
# 48600
# 48700
# 48800
# 48900
# 49000
# 49100
# 49200
# 49300
# 49400
# 49500
# 49600
# 49700
# 49800
# 49900
# 50000
# 50100
# 50200
# 50300
# 50400
# 50500
# 50600
# 50700
# 50800
# 50900
# 51000
# 51100
# 51200
# 51300
# 51400
# 51500
# 51600
# 51700
# 51800
# 51900
# 52000
# 52100
# 52200
# 52300
# 52400
# 52500
# 52600
# 52700
# 52800
# 52900
# 53000
# 53100
# 53200
# 53300
# 53400
# 53500
# 53600
# 53700
# 53800
# 53900
# 54000
# 54100
# 54200
# 54300
# 54400
# 54500
# 54600
# 54700
# 54800
# 54900
# 55000
# 55100
# 55200
# 55300
# 55400
# 55500
# 55600
# 55700
# 55800
# 55900
# 56000
# 56100
# 56200
# 56300
# 56400
# 56500
# 56600
# 56700
# 56800
# 56900
# 57000
# 57100
# 57200
# 57300
# 57400
# 57500
# 57600
# 57700
# 57800
# 57900
# 58000
# 58100
# 58200
# 58300
# 58400
# 58500
# 58600
# 58700
# 58800
# 58900
# 59000
# 59100
# 59200
# 59300
# 59400
# 59500
# 59600
# 59700
# 59800
# 59900
# 60000
# 60100
# 60200
# 60300
# 60400
# 60500
# 60600
# 60700
# 60800
# 60900
# 61000
# 61100
# 61200
# 61300
# 61400
# 61500
# 61600
# 61700
# 61800
# 61900
# 62000
# 62100
# 62200
# 62300
# 62400
# 62500
# 62600
# 62700
# 62800
# 62900
# 63000
# 63100
# 63200
# 63300
# 63400
# 63500
# 63600
# 63700
# 63800
# 63900
# 64000
# 64100
# 64200
# 64300
# 64400
# 64500
# 64600
# 64700
# 64800
# 64900
# 65000
# 65100
# 65200
# 65300
# 65400
# 65500
# 65600
# 65700
# 65800
# 65900
# 66000
# 66100
# 66200
# 66300
# 66400
# 66500
# 66600
# 66700
# 66800
# 66900
# 67000
# 67100
# 67200
# 67300
# 67400
# 67500
# 67600
# 67700
# 67800
# 67900
# 68000
# 68100
# 68200
# 68300
# 68400
# 68500
# 68600
# 68700
# 68800
# 68900
# 69000
# 69100
# 69200
# 69300
# 69400
# 69500
# 69600
# 69700
# 69800
# 69900
# 70000
# 70100
# 70200
# 70300
# 70400
# 70500
# 70600
# 70700
# 70800
# 70900
# 71000
# 71100
# 71200
# 71300
# 71400
# 71500
# 71600
# 71700
# 71800
# 71900
# 72000
# 72100
# 72200
# 72300
# 72400
# 72500
# 72600
# 72700
# 72800
# 72900
# 73000
# 73100
# 73200
# 73300
# 73400
# 73500
# 73600
# 73700
# 73800
# 73900
# 74000
# 74100
# 74200
# 74300
# 74400
# 74500
# 74600
# 74700
# 74800
# 74900
# 75000
# 75100
# 75200
# 75300
# 75400
# 75500
# 75600
# 75700
# 75800
# 75900
# 76000
# 76100
# 76200
# 76300
# 76400
# 76500
# 76600
# 76700
# 76800
# 76900
# 77000
# 77100
# 77200
# 77300
# 77400
# 77500
# 77600
# 77700
# 77800
# 77900
# 78000
# 78100
# 78200
# 78300
# 78400
# 78500
# 78600
# 78700
# 78800
# 78900
# 79000
# 79100
# 79200
# 79300
# 79400
# 79500
# 79600
# 79700
# 79800
# 79900
# 80000
# 80100
# 80200
# 80300
# 80400
# 80500
# 80600
# 80700
# 80800
# 80900
# 81000
# 81100
# 81200
# 81300
# 81400
# 81500
# 81600
# 81700
# 81800
# 81900
# 82000
# 82100
# 82200
# 82300
# 82400
# 82500
# 82600
# 82700
# 82800
# 82900
# 83000
# 83100
# 83200
# 83300
# 83400
# 83500
# 83600
# 83700
# 83800
# 83900
# 84000
# 84100
# 84200
# 84300
# 84400
# 84500
# 84600
# 84700
# 84800
# 84900
# 85000
# 85100
# 85200
# 85300
# 85400
# 85500
# 85600
# 85700
# 85800
# 85900
# 86000
# 86100
# 86200
# 86300
# 86400
# 86500
# 86600
# 86700
# 86800
# 86900
# 87000
# 87100
# 87200
# 87300
# 87400
# 87500
# 87600
# 87700
# 87800
# 87900
# 88000
# 88100
# 88200
# 88300
# 88400
# 88500
# 88600
# 88700
# 88800
# 88900
# 89000
# 89100
# 89200
# 89300
# 89400
# 89500
# 89600
# 89700
# 89800
# 89900
# 90000
# 90100
# 90200
# 90300
# 90400
# 90500
# 90600
# 90700
# 90800
# 90900
# 91000
# 91100
# 91200
# 91300
# 91400
# 91500
# 91600
# 91700
# 91800
# 91900
# 92000
# 92100
# 92200
# 92300
# 92400
# 92500
# 92600
# 92700
# 92800
# 92900
# 93000
# 93100
# 93200
# 93300
# 93400
# 93500
# 93600
# 93700
# 93800
# 93900
# 94000
# 94100
# 94200
# 94300
# 94400
# 94500
# 94600
# 94700
# 94800
# 94900
# 95000
# 95100
# 95200
# 95300
# 95400
# 95500
# 95600
# 95700
# 95800
# 95900
# 96000
# 96100
# 96200
# 96300
# 96400
# 96500
# 96600
# 96700
# 96800
# 96900
# 97000
# 97100
# 97200
# 97300
# 97400
# 97500
# 97600
# 97700
# 97800
# 97900
# 98000
# 98100
# 98200
# 98300
# 98400
# 98500
# 98600
# 98700
# 98800
# 98900
# 99000
# 99100
# 99200
# 99300
# 99400
# 99500
# 99600
# 99700
# 99800
# 99900
# 100000
# 100100
# 100200
# 100300
# 100400
# 100500
# 100600
# 100700
# 100800
# 100900
# 101000
# 101100
# 101200
# 101300
# 101400
# 101500
# 101600
# 101700
# /Users/david/.local/share/virtualenvs/selenium_parser-P8wiofQ8/lib/python3.10/site-packages/pandas/core/internals/construction.py:576: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [66], in <cell line: 15>()
#      12     if x % 100 == 0:
#      13         print(x)
# ---> 15 df_train = pd.DataFrame(train_rows, columns=['id', 'text', 'av', 'ac', 'pr', 'ui', 's', 'c', 'i', 'a', 'score'])
#      16 df_test = pd.DataFrame(test_rows, columns=['id', 'text', 'av', 'ac', 'pr', 'ui', 's', 'c', 'i', 'a', 'score'])
#      17 print(df_train.shape)
#
# File ~/.local/share/virtualenvs/selenium_parser-P8wiofQ8/lib/python3.10/site-packages/pandas/core/frame.py:737, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     729         mgr = arrays_to_mgr(
#     730             arrays,
#     731             columns,
#    (...)
#     734             typ=manager,
#     735         )
#     736     else:
# --> 737         mgr = ndarray_to_mgr(
#     738             data,
#     739             index,
#     740             columns,
#     741             dtype=dtype,
#     742             copy=copy,
#     743             typ=manager,
#     744         )
#     745 else:
#     746     mgr = dict_to_mgr(
#     747         {},
#     748         index,
#    (...)
#     751         typ=manager,
#     752     )
#
# File ~/.local/share/virtualenvs/selenium_parser-P8wiofQ8/lib/python3.10/site-packages/pandas/core/internals/construction.py:351, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     346 # _prep_ndarray ensures that values.ndim == 2 at this point
#     347 index, columns = _get_axes(
#     348     values.shape[0], values.shape[1], index=index, columns=columns
#     349 )
# --> 351 _check_values_indices_shape_match(values, index, columns)
#     353 if typ == "array":
#     355     if issubclass(values.dtype.type, str):
#
# File ~/.local/share/virtualenvs/selenium_parser-P8wiofQ8/lib/python3.10/site-packages/pandas/core/internals/construction.py:422, in _check_values_indices_shape_match(values, index, columns)
#     420 passed = values.shape
#     421 implied = (len(index), len(columns))
# --> 422 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (66734, 1), indices imply (66734, 11)

# %%
df_train = pd.DataFrame()
df_test = pd.DataFrame()

train_rows = []
test_rows = []

for index, row in df.iterrows():
    if row['id'] in train_id:
        train_rows.append(row)
    else:
        test_rows.append(row)

df_train = pd.DataFrame(train_rows, columns=['id', 'text', 'av', 'ac', 'pr', 'ui', 's', 'c', 'i', 'a', 'score'])
df_test = pd.DataFrame(test_rows, columns=['id', 'text', 'av', 'ac', 'pr', 'ui', 's', 'c', 'i', 'a', 'score'])
df_train.shape
# Out:
# (75999, 11)

# %%
df_test.shape
# Out:
# (25735, 11)

# %%
df_test.head()
# Out:
#                id                                               text av ac pr  \
# 1   CVE-2021-0002  Potential security vulnerabilities in some Int...  L  L  L
# 20  CVE-2021-0061  Potential security vulnerabilities in some Int...  L  L  L
# 21  CVE-2021-0062  Potential security vulnerabilities in some Int...  L  L  L
# 22  CVE-2021-0063  Potential security vulnerabilities in some Int...  A  L  N
# 28  CVE-2021-0071  Potential security vulnerabilities in some Int...  A  L  N
#
#    ui  s  c  i  a  score
# 1   N  U  H  N  H    7.1
# 20  N  U  H  H  H    7.8
# 21  N  U  H  H  H    7.8
# 22  N  U  N  N  H    6.5
# 28  N  U  H  H  H    8.8

# %%
75999 / (75999 + 25735)
# Out:
# 0.7470363890144888

# %%
dataset = Dataset.from_pandas(df)
dataset
# Out:
# Dataset({
#     features: ['id', 'text', 'av', 'ac', 'pr', 'ui', 's', 'c', 'i', 'a', 'score'],
#     num_rows: 101734
# })

# %%
dataset[0]
# Out:
# {'id': 'CVE-2021-0001',
#  'text': 'A potential security vulnerability in the Intel® Integrated Performance Primitives (IPP) Crypto Library may allow information disclosure. Intel® IPP is used by Intel® Software Guard Extension (SGX), and Intel is releasing software updates to mitigate this potential vulnerability. Observable timing discrepancy in Intel(R) IPP before version 2020 update 1 may allow authorized user to potentially enable information disclosure via local access.',
#  'av': 'L',
#  'ac': 'H',
#  'pr': 'L',
#  'ui': 'N',
#  's': 'U',
#  'c': 'H',
#  'i': 'N',
#  'a': 'N',
#  'score': 4.7}
