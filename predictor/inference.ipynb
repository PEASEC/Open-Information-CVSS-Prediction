# %% [markdown]
# # Notebook for running inference on Google Colab
#
# * Setup
# * Create pipeline
# * Run pipeline for each target var

# %% [markdown]
# ### Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp /content/drive/MyDrive/CVSS_Prediction/cvss_predictor.py .
# !cp /content/drive/MyDrive/CVSS_Prediction/CustomEvalTrainer.py .
# !pip install transformers datasets torch cvss
# !nvcc --version
# !nvidia-smi
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.19.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.2.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.11.0+cu113)
# Collecting cvss
#   Downloading cvss-2.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.3.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: cvss
# Successfully installed cvss-2.3
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0
# Mon May 16 13:20:18 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P0    31W /  70W |   1982MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from typing import Dict
import torch
import pandas as pd
from transformers import TextClassificationPipeline, AutoTokenizer, DistilBertTokenizerFast, AutoModelForSequenceClassification
from transformers.pipelines.base import GenericTensor
from tqdm.auto import tqdm
from cvss import CVSS3
from sklearn.metrics import mean_squared_error, mean_absolute_error

label_replacements = {
    'av': {
        'c2i': {'N': 0, 'L': 1, 'A': 2, 'P': 3},
        'i2c': {0: 'N', 1: 'L', 2: 'A', 3: 'P'}
    },
    'ac': {
        'c2i': {'L': 0, 'H': 1},
        'i2c': {0: 'L', 1: 'H'}
    },
    'pr': {
        'c2i': {'L': 0, 'H': 1, 'N': 2},
        'i2c': {0: 'L', 1: 'H', 2: 'N'}
    },
    'ui': {
        'c2i': {'R': 0, 'N': 1},
        'i2c': {0: 'R', 1: 'N'}
    },
    's': {
        'c2i': {'C': 0, 'U': 1},
        'i2c': {0: 'C', 1: 'U'}
    },
    'c': {
        'c2i': {'H': 0, 'N': 1, 'L': 2},
        'i2c': {0: 'H', 1: 'N', 2: 'L'}
    },
    'i': {
        'c2i': {'H': 0, 'N': 1, 'L': 2},
        'i2c': {0: 'H', 1: 'N', 2: 'L'}
    },
    'a': {
        'c2i': {'H': 0, 'N': 1, 'L': 2},
        'i2c': {0: 'H', 1: 'N', 2: 'L'}
    }
}

# %%
if not torch.cuda.is_available():
  print('No GPU detected')
else:
  n = torch.cuda.device_count()
  print(f'{n} GPU detected')
  gpu_info = str(torch.cuda.get_device_properties(0)).replace("_CudaDeviceProperties", "")
  print(f'Device {0}: "{gpu_info}"')
# Out:
# 1 GPU detected
# Device 0: "(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)"

# %%
dataset_path = "/content/drive/MyDrive/CVSS_Prediction/dataset/distilbert"
base_model = "distilbert-base-uncased"
checkpoint_path = "/content/drive/MyDrive/CVSS_Prediction/checkpoints_distilbert/"
target_vars = ['av', 'ac', 'pr', 'ui', 's', 'c', 'i', 'a']

# %% [markdown]
# ### Create Pipeline

# %%
class MyPipeline(TextClassificationPipeline):
    def preprocess(self, inputs, **tokenizer_kwargs) -> Dict[str, GenericTensor]:
        return_tensors = self.framework
        return self.tokenizer(inputs, return_tensors=return_tensors, truncation=True, **tokenizer_kwargs)

# %%
df = pd.read_json(f"{dataset_path}/test.json", orient='records', lines=True)
df = df.drop(columns=['input_ids', 'attention_mask'])

# %%
tokenizer: DistilBertTokenizerFast = AutoTokenizer.from_pretrained(base_model)

# %% [markdown]
# ### Run for each target var

# %%
for target_var in target_vars:
  print('-'*10 + target_var + '-'*10)
  number_of_labels = len(df[target_var].unique())
  df[f'predicted_{target_var}'] = pd.NaT * len(df)
  
  model_path = f"{checkpoint_path}distil_{target_var}/checkpoint-final"
  model = AutoModelForSequenceClassification.from_pretrained(model_path, num_labels=number_of_labels)
  pipe = MyPipeline(model=model, tokenizer=tokenizer, function_to_apply="softmax", device=0)

  replacements = label_replacements[target_var]['i2c']

  incorrect = 0

  total_n = len(df)

  for index, row in tqdm(df[:total_n].iterrows(), total=total_n):
    #print('-'*10 + f"{x}/{total_n}" + '-'*10)
    #print(row['id'] + ':' + target_var + '=' + row[target_var])
    out = pipe(row['text'])
    prediction = out[0]['label']
    prediction = prediction.replace('LABEL_', '')
    prediction = replacements[int(prediction)]
    df.at[index, f'predicted_{target_var}'] = prediction
    if prediction is not row[target_var]: incorrect += 1
    #print(f'Prediction: {prediction}')

  print(f"Incorrect: {incorrect}")
# Out:
# ----------av----------
#   0%|          | 0/25434 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/pipelines/base.py:998: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   UserWarning,
# Incorrect: 1762
# ----------ac----------
#   0%|          | 0/25434 [00:00<?, ?it/s]
# Incorrect: 1103
# ----------pr----------
#   0%|          | 0/25434 [00:00<?, ?it/s]
# Incorrect: 3316
# ----------ui----------
#   0%|          | 0/25434 [00:00<?, ?it/s]
# Incorrect: 1382
# ----------s----------
#   0%|          | 0/25434 [00:00<?, ?it/s]
# Incorrect: 960
# ----------c----------
#   0%|          | 0/25434 [00:00<?, ?it/s]
# Incorrect: 2866
# ----------i----------
#   0%|          | 0/25434 [00:00<?, ?it/s]
# Incorrect: 2633
# ----------a----------
#   0%|          | 0/25434 [00:00<?, ?it/s]
# Incorrect: 2429

# %% [markdown]
# ### Inspect results

# %%
df.head(50)
# Out:
#                id                                               text av ac pr  \
# 0   CVE-2016-0003  Microsoft Edge allows remote attackers to exec...  N  L  N
# 1   CVE-2016-0003  This vulnerability allows remote attackers to ...  N  L  N
# 2   CVE-2016-0011  Microsoft SharePoint Server 2013 SP1 and Share...  N  L  L
# 3   CVE-2016-0016  Microsoft Windows Vista SP2, Windows Server 20...  L  L  L
# 4   CVE-2016-0021  Microsoft InfoPath 2007 SP3, 2010 SP2, and 201...  L  L  N
# 5   CVE-2016-0025  Microsoft Word 2007 SP3, Office 2010 SP2, Word...  L  L  L
# 6   CVE-2016-0030  Cross-site scripting (XSS) vulnerability in Ou...  N  L  N
# 7   CVE-2016-0034  Microsoft Silverlight 5 before 5.1.41212.0 mis...  N  L  N
# 8   CVE-2016-0037  The forms-based authentication implementation ...  N  L  N
# 9   CVE-2016-0041  Microsoft Windows Vista SP2, Windows Server 20...  L  L  L
# 10  CVE-2016-0047  WinForms in Microsoft .NET Framework 2.0 SP2, ...  N  L  N
# 11  CVE-2016-0050  Network Policy Server (NPS) in Microsoft Windo...  N  L  N
# 12  CVE-2016-0054  Microsoft Excel 2007 SP3, Excel 2010 SP2, Exce...  L  L  N
# 13  CVE-2016-0058  Buffer overflow in the PDF Library in Microsof...  L  L  N
# 14  CVE-2016-0061  Microsoft Internet Explorer 9 through 11 and M...  N  L  N
# 15  CVE-2016-0061  This vulnerability allows remote attackers to ...  N  L  N
# 16  CVE-2016-0067  Microsoft Internet Explorer 9 through 11 allow...  N  L  N
# 17  CVE-2016-0071  Microsoft Internet Explorer 9 allows remote at...  N  L  N
# 18  CVE-2016-0075  The kernel in Microsoft Windows 8.1, Windows S...  L  L  N
# 19  CVE-2016-0084  Microsoft Edge allows remote attackers to exec...  N  L  N
# 20  CVE-2016-0090  Hyper-V in Microsoft Windows 8.1, Windows Serv...  L  L  N
# 21  CVE-2016-0093  The kernel-mode driver in Microsoft Windows Vi...  L  L  L
# 22  CVE-2016-0096  The kernel-mode driver in Microsoft Windows Vi...  L  L  L
# 23  CVE-2016-0100  Microsoft Windows Vista SP2 and Server 2008 SP...  L  L  N
# 24  CVE-2016-0104  Microsoft Internet Explorer 10 allows remote a...  N  H  N
# 25  CVE-2016-0107  Microsoft Internet Explorer 9 through 11 allow...  N  H  N
# 26  CVE-2016-0107  This vulnerability allows remote attackers to ...  N  H  N
# 27  CVE-2016-0112  Microsoft Internet Explorer 9 through 11 allow...  N  H  N
# 28  CVE-2016-0112  This vulnerability allows remote attackers to ...  N  H  N
# 29  CVE-2016-0112  This vulnerability allows remote attackers to ...  N  H  N
# 30  CVE-2016-0121  The Adobe Type Manager Library in Microsoft Wi...  N  L  N
# 31  CVE-2016-0124  Microsoft Edge allows remote attackers to exec...  N  H  N
# 32  CVE-2016-0128  The SAM and LSAD protocol implementations in M...  N  H  N
# 33  CVE-2016-0133  The USB Mass Storage Class driver in Microsoft...  P  L  N
# 34  CVE-2016-0137  The Click-to-Run (C2R) implementation in Micro...  L  L  N
# 35  CVE-2016-0141  The Visual Basic macros in Microsoft Office 20...  N  L  N
# 36  CVE-2016-0147  Microsoft XML Core Services 3.0 allows remote ...  N  L  N
# 37  CVE-2016-0150  HTTP.sys in Microsoft Windows 10 Gold and 1511...  N  L  N
# 38  CVE-2016-0154  Microsoft Internet Explorer 9 through 11 and M...  N  H  N
# 39  CVE-2016-0158  Microsoft Edge allows remote attackers to bypa...  N  L  N
# 40  CVE-2016-0158  This vulnerability allows remote attackers to ...  N  L  N
# 41  CVE-2016-0164  Microsoft Internet Explorer 10 and 11 allows r...  N  H  N
# 42  CVE-2016-0167  The kernel-mode driver in Microsoft Windows Vi...  L  L  L
# 43  CVE-2016-0171  The kernel-mode drivers in Microsoft Windows V...  L  L  L
# 44  CVE-2016-0175  The kernel-mode drivers in Microsoft Windows V...  L  L  L
# 45  CVE-2016-0175  This vulnerability allows local attackers to e...  L  L  L
# 46  CVE-2016-0181  Microsoft Windows 10 Gold and 1511 allows loca...  L  L  L
# 47  CVE-2016-0185  Media Center in Microsoft Windows Vista SP2, W...  L  L  N
# 48  CVE-2016-0185  This vulnerability allows remote attackers to ...  L  L  N
# 49  CVE-2016-0190  Volume Manager Driver in Microsoft Windows 8.1...  L  L  L
#
#    ui  s  c  i  a  score predicted_av predicted_ac predicted_pr predicted_ui  \
# 0   R  C  H  H  H    9.6            N            H            N            R
# 1   R  C  H  H  H    9.6            N            L            N            R
# 2   R  C  L  L  N    5.4            N            L            L            R
# 3   N  U  H  H  H    7.8            L            L            L            N
# 4   R  U  H  H  H    7.8            L            L            N            R
# 5   R  U  H  H  H    7.3            L            L            N            R
# 6   R  C  L  L  N    6.1            N            L            N            R
# 7   R  U  H  H  H    8.8            N            L            N            R
# 8   N  U  N  N  H    7.5            N            L            N            N
# 9   N  U  H  H  H    7.8            L            L            L            N
# 10  N  U  H  N  N    7.5            N            L            N            N
# 11  N  U  N  N  L    5.3            N            H            N            N
# 12  R  U  H  H  H    7.8            L            L            N            R
# 13  R  U  H  H  H    7.8            L            L            N            R
# 14  R  U  H  H  H    8.8            N            H            N            R
# 15  R  U  H  H  H    8.8            N            H            N            R
# 16  R  U  H  H  H    8.8            N            L            N            R
# 17  R  U  H  H  H    8.8            N            H            N            R
# 18  R  U  H  N  N    5.5            L            L            L            R
# 19  R  U  H  H  H    8.8            N            H            N            R
# 20  N  C  H  N  N    7.1            L            L            H            N
# 21  N  U  H  H  H    7.8            L            L            L            N
# 22  N  U  H  H  H    7.8            L            L            L            N
# 23  N  U  H  H  H    8.4            L            L            L            N
# 24  R  U  H  H  H    7.5            N            H            N            R
# 25  R  U  H  H  H    7.5            N            L            N            R
# 26  R  U  H  H  H    7.5            N            H            N            R
# 27  R  U  H  H  H    7.5            N            L            N            R
# 28  R  U  H  H  H    7.5            N            L            N            R
# 29  R  U  H  H  H    7.5            N            H            N            R
# 30  R  U  H  H  H    8.8            N            L            N            R
# 31  R  U  H  H  H    7.5            N            H            N            R
# 32  R  U  H  H  N    6.8            N            H            N            R
# 33  N  U  H  H  H    6.8            P            L            L            N
# 34  R  U  L  N  N    3.3            L            L            L            N
# 35  R  U  H  N  N    6.5            N            L            N            N
# 36  R  U  H  H  H    8.8            N            L            N            R
# 37  N  U  N  N  H    7.5            N            L            N            N
# 38  R  U  H  H  H    7.5            N            H            N            R
# 39  R  U  N  H  N    6.5            N            L            N            R
# 40  R  U  N  H  N    6.5            N            L            N            R
# 41  R  U  H  H  H    7.5            N            H            N            R
# 42  N  U  H  H  H    7.8            L            L            L            N
# 43  N  U  H  H  H    7.8            L            L            L            N
# 44  N  U  L  N  N    3.3            L            L            L            N
# 45  N  U  L  N  N    3.3            L            L            N            N
# 46  N  U  N  H  N    5.5            L            L            L            N
# 47  R  U  H  H  H    7.8            L            L            N            R
# 48  R  U  H  H  H    7.8            N            H            N            R
# 49  N  U  H  N  N    5.5            L            L            L            N
#
#    predicted_s predicted_c predicted_i predicted_a
# 0            U           H           H           H
# 1            U           H           H           H
# 2            C           L           L           N
# 3            U           H           H           H
# 4            U           H           H           H
# 5            U           H           H           H
# 6            C           L           L           N
# 7            U           H           H           H
# 8            U           N           N           H
# 9            U           H           H           H
# 10           U           H           N           N
# 11           U           N           N           H
# 12           U           H           H           H
# 13           U           H           H           H
# 14           U           H           H           H
# 15           U           H           H           H
# 16           U           H           H           H
# 17           U           H           H           H
# 18           U           H           N           N
# 19           U           H           H           H
# 20           C           H           N           N
# 21           U           H           H           H
# 22           U           H           H           H
# 23           U           H           H           H
# 24           U           H           H           H
# 25           U           H           H           H
# 26           U           H           H           H
# 27           U           H           H           H
# 28           U           H           H           H
# 29           U           H           N           N
# 30           U           H           H           H
# 31           U           H           H           H
# 32           U           N           H           N
# 33           U           H           H           H
# 34           U           L           N           N
# 35           U           H           N           N
# 36           U           H           H           H
# 37           U           N           N           H
# 38           U           H           H           H
# 39           U           N           H           N
# 40           U           L           L           N
# 41           U           H           H           H
# 42           U           H           H           H
# 43           U           H           H           H
# 44           U           H           N           N
# 45           U           H           H           H
# 46           U           H           L           H
# 47           U           H           H           H
# 48           C           H           H           H
# 49           U           H           N           N

# %%
total_n = len(df)

for index, row in tqdm(df[:total_n].iterrows(), total=total_n):
  vector = f"CVSS:3.0/AV:{row['predicted_av']}/AC:{row['predicted_ac']}/PR:{row['predicted_pr']}/UI:{row['predicted_ui']}/S:{row['predicted_s']}/C:{row['predicted_c']}/I:{row['predicted_i']}/A:{row['predicted_a']}"
  c = CVSS3(vector)
  base_score = c.scores()[0]
  df.at[index, 'predicted_score'] = base_score
# Out:
#   0%|          | 0/25434 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#               id                                               text av ac pr  \
# 0  CVE-2016-0003  Microsoft Edge allows remote attackers to exec...  N  L  N
# 1  CVE-2016-0003  This vulnerability allows remote attackers to ...  N  L  N
# 2  CVE-2016-0011  Microsoft SharePoint Server 2013 SP1 and Share...  N  L  L
# 3  CVE-2016-0016  Microsoft Windows Vista SP2, Windows Server 20...  L  L  L
# 4  CVE-2016-0021  Microsoft InfoPath 2007 SP3, 2010 SP2, and 201...  L  L  N
#
#   ui  s  c  i  a  score predicted_av predicted_ac predicted_pr predicted_ui  \
# 0  R  C  H  H  H    9.6            N            H            N            R
# 1  R  C  H  H  H    9.6            N            L            N            R
# 2  R  C  L  L  N    5.4            N            L            L            R
# 3  N  U  H  H  H    7.8            L            L            L            N
# 4  R  U  H  H  H    7.8            L            L            N            R
#
#   predicted_s predicted_c predicted_i predicted_a  predicted_score
# 0           U           H           H           H              7.5
# 1           U           H           H           H              8.8
# 2           C           L           L           N              5.4
# 3           U           H           H           H              7.8
# 4           U           H           H           H              7.8

# %%
df.to_csv("/content/drive/MyDrive/CVSS_Prediction/predictions.csv")

# %%
score_true = df['score']
score_predicted = df['predicted_score']
print(len(score_true))
print(len(score_predicted))

# %%
mean_squared_error(y_true=score_true, y_pred=score_predicted)

# %%
mean_absolute_error(y_true=score_true, y_pred=score_predicted)
