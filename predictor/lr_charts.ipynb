# %%
from typing import List

import pandas as pd
from pandas import DataFrame
from pymongo import MongoClient
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure

sns.set_style("white")

# %%
data = [0.4819009594426677,0.8349173204595496,0.8369818591582971,0.8329987427555835,0.8359233816427074,0.8379668842019143,0.8388406171873091]

# %%
# plot
fig, ax = plt.subplots(figsize=(10,7), dpi= 80)

plt.plot(np.array(range(0, 7)), data)
plt.xlabel('Epoche', fontsize=14)
plt.ylabel('f1', fontsize=14)
plt.xlim(0, 6)
plt.ylim(0, 1)

#ax.set(xlim=(0, 1), ylim=(0, 1))
plt.savefig('../assets/av_eval_f1_distil.png')
plt.show()

# %%
data = [0.21032971024784808, 0.7984264481419608, 0.819623340470784, 0.8295301832587041, 0.8355405304968717, 0.8307027517774187, 0.832138954215226]
# plot
fig, ax = plt.subplots(figsize=(10,7), dpi= 80)

plt.plot(np.array(range(0, 7)), data)
plt.xlabel('Epoche')
plt.ylabel('f1')
plt.xlim(0, 6)
plt.ylim(0, 1)

#ax.set(xlim=(0, 1), ylim=(0, 1))
plt.savefig('../assets/av_eval_f1_bert-small.png')
plt.show()
